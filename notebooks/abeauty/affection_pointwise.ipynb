# %%
MODEL_CLS = "affection"
DATASET = "abeauty"
STRATEGY = "pointwise"
PATH_WORK_DIR = "../.."

# %%
if DATASET=="abeauty":
    NUM_USERS = 3819
    NUM_ITEMS = 1581
elif DATASET=="amusic":
    NUM_USERS = 5541
    NUM_ITEMS = 3568
elif DATASET=="lastfm":
    NUM_USERS = 1892
    NUM_ITEMS = 17632
elif DATASET=="movielens":
    NUM_USERS = 610
    NUM_ITEMS = 9724
else:
    raise ValueError()

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import os
os.environ["CUDA_LAUNCH_BLOCKING"] = "1"
os.chdir(PATH_WORK_DIR)
print(f"DIRECTORY: {os.getcwd()}")
# Out:
# DIRECTORY: c:\Users\jayar\Desktop\바탕 화면\REPO\PAPER REVIEW\RECSYS\02_MLP\10_RS-DRNet

# %%
import sys
sys.path.append("src")

# %% [markdown]
# # Config

# %%
import pandas as pd
from pointwise import config, datamodule, trainer, evaluator, utils
import drnet

# %%
PATH = f"./config/{MODEL_CLS}_{STRATEGY}.yaml"
cfg = config.build(PATH)

# %%
utils.seed.main(cfg.seed)
# Out:
# ALL SEEDS RESET: 42

# %% [markdown]
# # Data Preparation

# %%
PATH = f"./data/{DATASET}.csv"
df = pd.read_csv(PATH)

# %%
kwargs = dict(
    df=df,
    percentile=0.9,
)

utils.desc.main(**kwargs)
# Out:
# number of user: 3819
# number of item: 1581
# total interaction: 34278
# interaction density: 0.5677 %
# max interaction of user: 127
# max interaction of item: 1221
# top 10.0 % interaction of user: 15.0
# top 10.0 % interaction of item: 30.0
# mean interaction of user: 8
# mean interaction of item: 21

# %%
kwargs = dict(
    df=df,
    cfg=cfg.datamodule,
)

dataloaders, _ = datamodule.build(**kwargs)

# %% [markdown]
# # Modeling

# %%
kwargs = dict(
    num_users=NUM_USERS,
    num_items=NUM_ITEMS,
    **cfg.model.params,
)

model = drnet.affection.AffectionNetworks(**kwargs)

# %% [markdown]
# # Train

# %%
kwargs = dict(
    model=model,
    cfg=cfg.trainer,
)

opt = trainer.build(**kwargs)

# %%
kwargs = dict(
    trn_loader=dataloaders["trn"],
    val_loader=dataloaders["val"],
)

records = opt.fit(**kwargs)
# Out:
# BEST EPOCH: 28
# BEST SCORE: 0.6487

# %%
kwargs = dict(
    records=records,
    suptitle="Affection Training History",
    trn="BCE",
    val="NDCG@10",
    figsize=(7,3),
)

utils.visualizer.main(**kwargs)

# %% [markdown]
# # Test

# %%
kwargs = dict(
    model=model,
    cutoff=[5,10,15,20,25,50],
)

msr = evaluator.build(**kwargs)

# %%
result, metrics_sheet = msr(dataloaders["tst"])
# Out:
# TST: 100%|██████████| 438/438 [00:01<00:00, 262.52it/s]

# %%
metrics_sheet
# Out:
#     k  hit_ratio  precision    recall       map      ndcg
# 0   5   0.570979   0.151771  0.569888  0.596562  0.521852
# 1  10   0.649961   0.100656  0.660456  0.758006  0.547538
# 2  15   0.714248   0.076480  0.726968  0.830965  0.564022
# 3  20   0.764629   0.060234  0.776819  0.833907  0.576130
# 4  25   0.812123   0.050328  0.823389  0.836063  0.586623
# 5  50   0.935450   0.028098  0.949309  0.839991  0.611795

# %% [markdown]
# # Save

# %%
PATH = f'./checkpoints/{DATASET}/{MODEL_CLS}_{STRATEGY}.pth'

kwargs = dict(
    obj=model,
    path=PATH,
)

utils.checkpointer.save(**kwargs)
